# %% [markdown]
# # Exempel på användning av jupyterlab för att köra pytest
#
# Här visar jag hur du kan använda jupyterlab för att laborera och lära dig mer om pytest.
# Börja med att installera och sätta upp ipytest, detta steg kör du bara en gång.
#
# Sedan:
# * Skriv din kod (den som skall testas)
# * Skriv sedan dina tester (de som testar koden)
# * Kör testerna
#
# De här tre stegen kan du ändra, köra igen och ändra igen och köra igen.
# Tänk bara på att köra stegen i ordning.

# %%
# Börja med att installera och sätta upp ipytest (detta gör du en gång)
# !pip install pytest ipytest

import ipytest
ipytest.autoconfig()
# Out:
# Requirement already satisfied: pytest in /opt/homebrew/anaconda3/lib/python3.12/site-packages (7.4.4)
# Requirement already satisfied: ipytest in /opt/homebrew/anaconda3/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: iniconfig in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pytest) (1.1.1)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pytest) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pytest) (1.0.0)
# Requirement already satisfied: ipython in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipytest) (8.25.0)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (2.15.1)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython->ipytest) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython->ipytest) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.5)
# Requirement already satisfied: executing in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipytest) (0.8.3)
# Requirement already satisfied: asttokens in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipytest) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->ipytest) (0.2.2)
# Requirement already satisfied: six in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from asttokens->stack-data->ipython->ipytest) (1.16.0)

# %%
# Här skriver du din kod (ditt python-skript)
def add(a, b):
    return a + b

def divide(a, b):
    if b == 0:
        raise ValueError("Division by zero")
    return a / b

# %%
# Här skriver du dina pytest-tester
# Tänk på att de skall börja med test_

def test_add():
    assert add(2, 3) == 5
    assert add(-1, 1) == 0

def test_divide():
    assert divide(10, 2) == 5

# %%
# Kör testerna
ipytest.run("-vv")   # -vv ger mer detaljerad output
# Out:
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-7.4.4, pluggy-1.0.0 -- /opt/homebrew/anaconda3/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/jonas/g/kurs-testning-python/jupyterlab
# plugins: anyio-4.2.0
# collecting ... collected 2 items
#
# t_35a2f27f244645df9f9f72ede98bf28f.py::test_add PASSED                                       [ 50%]
# t_35a2f27f244645df9f9f72ede98bf28f.py::test_divide PASSED                                    [100%]
#
# ======================================== 2 passed in 0.01s =========================================
# <ExitCode.OK: 0>
